# %% [markdown]
# ## pg_restore cipsrv_nhdplustopo_h

# %%
import os,sys,psycopg2,argparse;
from ipywidgets import IntProgress,HTML,VBox;
from IPython.display import display;
from contextlib import closing;
parser = argparse.ArgumentParser();
parser.add_argument("--hrtp_dumpfile"    ,required=False);
parser.add_argument("--use_existing"     ,required=False,default=False,action=argparse.BooleanOptionalAction);
parser.add_argument("--override_username",required=False);
args, _ = parser.parse_known_args();

sys.path.append(os.path.join(os.path.expanduser('~'),'notebooks'));
import common;

s3bk = os.environ['S3_BUCKET'];
# override: s3bk = 'https://edap-ow-data-commons.s3.amazonaws.com/data/';
lddk = os.path.join(os.path.expanduser('~'),'loading_dock');
dbse = os.environ['POSTGRESQL_DB'];
host = os.environ['POSTGRESQL_HOST'];
port = os.environ['POSTGRESQL_PORT'];
user = 'cipsrv';
pswd = os.environ['POSTGRESQL_CIP_PASS'];
thds = 2;

component_name = 'cipsrv_nhdplustopo_h';
component_type = 'dataset';
if args.hrtp_dumpfile is None:
   src = 'cipsrv_nhdplustopo_h_beta_1.dmp';
else:
   src = args.hrtp_dumpfile;

print("source: " + s3bk + src);

# %%
if args.use_existing:
    print("using existing " + src);

else:
    z = common.download(
        s3  = s3bk
       ,src = src
       ,ld  = lddk
       ,trg = src
    );

    if not os.path.exists(os.path.join(lddk,src)):
        raise Exception('failed to download dmp file');

    print("successfully downloaded " + src);

# %%
cs = "dbname=%s user=%s password=%s host=%s port=%s" % (
     dbse
    ,user
    ,pswd
    ,host
    ,port
);

try:
    conn = psycopg2.connect(cs);
except:
    raise Exception("database connection error");

print("database is ready");

# %%
with closing(conn.cursor()) as cursor:
    cursor.execute("SELECT topology.DropTopology('cipsrv_nhdplustopo_h_catchment_fabric_3338')  WHERE EXISTS (SELECT * FROM topology.topology WHERE name = 'cipsrv_nhdplustopo_h_catchment_fabric_3338')");
    cursor.execute("SELECT topology.DropTopology('cipsrv_nhdplustopo_h_catchment_fabric_5070')  WHERE EXISTS (SELECT * FROM topology.topology WHERE name = 'cipsrv_nhdplustopo_h_catchment_fabric_5070')");
    cursor.execute("SELECT topology.DropTopology('cipsrv_nhdplustopo_h_catchment_fabric_26904') WHERE EXISTS (SELECT * FROM topology.topology WHERE name = 'cipsrv_nhdplustopo_h_catchment_fabric_26904')");
    cursor.execute("SELECT topology.DropTopology('cipsrv_nhdplustopo_h_catchment_fabric_32161') WHERE EXISTS (SELECT * FROM topology.topology WHERE name = 'cipsrv_nhdplustopo_h_catchment_fabric_32161')");
    cursor.execute("SELECT topology.DropTopology('cipsrv_nhdplustopo_h_catchment_fabric_32655') WHERE EXISTS (SELECT * FROM topology.topology WHERE name = 'cipsrv_nhdplustopo_h_catchment_fabric_32655')");
    cursor.execute("SELECT topology.DropTopology('cipsrv_nhdplustopo_h_catchment_fabric_32702') WHERE EXISTS (SELECT * FROM topology.topology WHERE name = 'cipsrv_nhdplustopo_h_catchment_fabric_32702')");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplustopo_h.catchment_3338_topo CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplustopo_h.catchment_5070_topo CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplustopo_h.catchment_26904_topo CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplustopo_h.catchment_32161_topo CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplustopo_h.catchment_32655_topo CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplustopo_h.catchment_32702_topo CASCADE");
    conn.commit();

print("preexisting data purged.");

# %%
z = common.pg_restore(
     host
    ,port
    ,dbse
    ,user
    ,pswd
    ,os.path.join(lddk,src)
    ,thds
);

print("pg_restore complete.");

# %%
if z[0] == b'':
    a = common.upsert_registry(conn,component_name,component_type,src,override_username);
else:
    print(str(z));
    sys.exit(-10);
