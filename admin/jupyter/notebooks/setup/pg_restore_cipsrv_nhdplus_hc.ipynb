# %% [markdown]
# ## pg_restore cipsrv_nhdplus_hc - Temp and Precip NHDPlus data

# %%
import os,sys,psycopg2,argparse;
from ipywidgets import IntProgress,HTML,VBox;
from IPython.display import display;
from contextlib import closing;
parser = argparse.ArgumentParser();
parser.add_argument("--hrc_dumpfile"     ,required=False);
parser.add_argument("--use_existing"     ,required=False,default=False,action=argparse.BooleanOptionalAction);
parser.add_argument("--override_username",required=False);
args, _ = parser.parse_known_args();

sys.path.append(os.path.join(os.path.expanduser('~'),'notebooks'));
import common;

s3bk = os.environ['S3_BUCKET'];
# override: s3bk = 'https://edap-ow-data-commons.s3.amazonaws.com/data/';
lddk = os.path.join(os.path.expanduser('~'),'loading_dock');
dbse = os.environ['POSTGRESQL_DB'];
host = os.environ['POSTGRESQL_HOST'];
port = os.environ['POSTGRESQL_PORT'];
user = 'cipsrv';
pswd = os.environ['POSTGRESQL_CIP_PASS'];
thds = 2;

component_name = 'cipsrv_nhdplus_hc';
component_type = 'dataset';
if args.hrc_dumpfile is None:
   src = 'cipsrv_nhdplus_h_betac_1.dmp';
else:
   src = args.hrc_dumpfile;

print("source: " + s3bk + src);

# %%
if args.use_existing:
    print("using existing " + src);

else:
    z = common.download(
        s3  = s3bk
       ,src = src
       ,ld  = lddk
       ,trg = src
    );

    if not os.path.exists(os.path.join(lddk,src)):
        raise Exception('failed to download dmp file');

    print("successfully downloaded " + src);

# %%
cs = "dbname=%s user=%s password=%s host=%s port=%s" % (
     dbse
    ,user
    ,pswd
    ,host
    ,port
);

try:
    conn = psycopg2.connect(cs);
except:
    raise Exception("database connection error");

print("database is ready");

# %%
with closing(conn.cursor()) as cursor:
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivnlcd2011 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivprecipmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivroma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumdivtempmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotnlcd2011 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotprecipmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtotroma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluscumtottempmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluseromma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdpluserommm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrlat CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrnlcd2011 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrprecipmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrroma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_h.nhdplusincrtempmm12 CASCADE");
    conn.commit();

print("preexisting data purged.");

# %%
z = common.pg_restore(
     host
    ,port
    ,dbse
    ,user
    ,pswd
    ,os.path.join(lddk,src)
    ,thds
);

print("pg_restore complete.");

# %%
if z[0] == b'':
    a = common.upsert_registry(conn,component_name,component_type,src,args.override_username);
else:
    print(str(z));
    sys.exit(-10);
