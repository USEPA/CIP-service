# %% [markdown]
# ## pg_restore cipsrv_nhdplus_mc - Temp and Precip NHDPLus data

# %%
import os,sys,psycopg2,argparse;
from ipywidgets import IntProgress,HTML,VBox;
from IPython.display import display;
from contextlib import closing;
parser = argparse.ArgumentParser();
parser.add_argument("--mrc_dumpfile"     ,required=False);
parser.add_argument("--use_existing"     ,required=False,default=False,action=argparse.BooleanOptionalAction);
parser.add_argument("--override_username",required=False);
args, _ = parser.parse_known_args();

sys.path.append(os.path.join(os.path.expanduser('~'),'notebooks'));
import common;

s3bk = os.environ['S3_BUCKET'];
# override: s3bk = 'https://edap-ow-data-commons.s3.amazonaws.com/data/';
lddk = os.path.join(os.path.expanduser('~'),'loading_dock');
dbse = os.environ['POSTGRESQL_DB'];
host = os.environ['POSTGRESQL_HOST'];
port = os.environ['POSTGRESQL_PORT'];
user = 'cipsrv';
pswd = os.environ['POSTGRESQL_CIP_PASS'];
thds = 2;

component_name = 'cipsrv_nhdplus_mc';
component_type = 'dataset';
if args.mrc_dumpfile is None:
   src = 'cipsrv_nhdplus_m_v21c_1.dmp';
else:
   src = args.mr_dumpfile;

print("source: " + s3bk + src);

# %%
if args.use_existing:
    print("using existing " + src);

else:
    z = common.download(
        s3  = s3bk
       ,src = src
       ,ld  = lddk
       ,trg = src
    );

    if not os.path.exists(os.path.join(lddk,src)):
        raise Exception('failed to download dmp file');

    print("successfully downloaded " + src);

# %%
cs = "dbname=%s user=%s password=%s host=%s port=%s" % (
     dbse
    ,user
    ,pswd
    ,host
    ,port
);

try:
    conn = psycopg2.connect(cs);
except:
    raise Exception("database connection error");

print("database is ready");

# %%
with closing(conn.cursor()) as cursor:
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivnlcd2011 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivprecipmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivroma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumdivtempmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotnlcd2011 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotprecipmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtotroma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluscumtottempmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluseromma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdpluserommm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrlat CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrnlcd2011 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrprecipmm12 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrroma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempma CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm01 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm02 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm03 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm04 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm05 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm06 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm07 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm08 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm09 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm10 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm11 CASCADE");
    cursor.execute("DROP TABLE IF EXISTS cipsrv_nhdplus_m.nhdplusincrtempmm12 CASCADE");
    conn.commit();

print("preexisting data purged.");

# %%
z = common.pg_restore(
     host
    ,port
    ,dbse
    ,user
    ,pswd
    ,os.path.join(lddk,src)
    ,thds
);

print("pg_restore complete.");

# %%
if z[0] == b'':
    a = common.upsert_registry(conn,component_name,component_type,src,args.override_username);
else:
    print(str(z));
    sys.exit(-10);
