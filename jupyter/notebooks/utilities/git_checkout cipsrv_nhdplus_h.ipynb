# %% [markdown]
# ## git_checkout cipsrv_nhdplus_h

# %%
import os,sys,git,tempfile,psycopg2;
from ipywidgets import IntProgress,HTML,VBox;
from IPython.display import display;

sys.path.append(os.path.join(os.path.expanduser('~'),'notebooks'));
import common;

gith = os.environ['GITHUB_REPO_URL'];
# override: "git@github.com:USEPA/CIPv2.git"
brnh = os.environ['GITHUB_DEFAULT_BRANCH'];
# override: "mybranch"

dbse = os.environ['POSTGRES_DB'];
host = os.environ['POSTGRES_HOST'];
port = os.environ['POSTGRES_PORT'];
user = 'cipsrv';
pasw = os.environ['POSTGRES_CIP_PASS'];

depf = os.path.join('cip','database','cipsrv_nhdplus_h','cipsrv_nhdplus_h_deploy.sql');

# %%
cs = "dbname=%s user=%s password=%s host=%s port=%s" % (
     dbse
    ,user
    ,pasw
    ,host
    ,port
);

try:
    conn = psycopg2.connect(cs);
except:
    raise Exception("database connection error");

# %%
td = tempfile.TemporaryDirectory();

repo = git.Repo.clone_from(
     url     = gith
    ,branch  = brnh
    ,to_path = td.name 
    ,depth   = 1
);

# %%
trg = os.path.join(td.name,depf);

if not os.path.exists(trg):
    raise Exception(trg + ' file not found.');
    
z = common.load_sqlfile(conn,trg,echo=True);
# Out:
# DROP MATERIALIZED VIEW
# SELECT 21721009
# ALTER TABLE
# GRANT
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# DROP MATERIALIZED VIEW
# SELECT 9059195
# ALTER TABLE
# GRANT
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# DROP MATERIALIZED VIEW
# SELECT 2517706
# ALTER TABLE
# GRANT
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# DROP MATERIALIZED VIEW
# SELECT 23350210
# ALTER TABLE
# GRANT
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# DROP MATERIALIZED VIEW
# SELECT 32736
# ALTER TABLE
# GRANT
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# DROP MATERIALIZED VIEW
# SELECT 40419
# ALTER TABLE
# GRANT
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# DROP MATERIALIZED VIEW
# SELECT 6312
# ALTER TABLE
# GRANT
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# DROP MATERIALIZED VIEW
# SELECT 3499
# ALTER TABLE
# GRANT
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# ANALYZE
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION
# GRANT
# CREATE FUNCTION
# ALTER FUNCTION

# %%
conn.close();
td.cleanup();
